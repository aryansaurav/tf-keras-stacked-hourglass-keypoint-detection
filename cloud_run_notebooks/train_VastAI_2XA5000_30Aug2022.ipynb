# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
import os, sys, argparse
import tensorflow.keras.backend as K
#from tensorflow.keras.utils import multi_gpu_model
from tensorflow.keras.callbacks import TensorBoard, TerminateOnNaN

from hourglass.model import get_hourglass_model
from hourglass.data import hourglass_dataset
from hourglass.loss import get_loss
from hourglass.callbacks import EvalCallBack, CheckpointCleanCallBack
from common.utils import get_classes, get_matchpoints, get_model_type, optimize_tf_gpu
from common.model_utils import get_optimizer

# Try to enable Auto Mixed Precision on TF 2.0
# os.environ['TF_ENABLE_AUTO_MIXED_PRECISION'] = '1'
# os.environ['TF_AUTO_MIXED_PRECISION_GRAPH_REWRITE_IGNORE_PERFORMANCE'] = '1'
# os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import tensorflow as tf
# optimize_tf_gpu(tf, K)

# %%
# Arguments parsed from command line can be set here
# Model definition options:
num_stacks=2
mobile=False
tiny=False
model_input_shape="256x256"
weights_path=None

# Data options
dataset_path="data/mpii"
classes_path="configs/mpii_classes.txt"
matchpoint_path="configs/mpii_match_point.txt"

# Training options
batch_size=64
optimizer="RMSProp"
loss_type="mse"
learning_rate=5e-4
decay_type=None
mixed_precision=False
init_epoch=0
total_epoch=100
gpu_num=2

height, width = model_input_shape.split('x')
model_input_shape = (int(height), int(width)) 
orig_img_shape = (1280, 720)    # Height and width in pixels of input images, can be read from file or manually specified

# %%
# def main(args):
log_dir = 'logs/000'
os.makedirs(log_dir, exist_ok=True)

class_names = get_classes(classes_path)
num_classes = len(class_names)
if matchpoint_path:
    matchpoints = get_matchpoints(matchpoint_path)
else:
    matchpoints = None

# choose model type
if tiny:
    num_channels = 128
else:
    num_channels = 256

if mixed_precision:
    tf_major_version = float(tf.__version__[:3])
    if tf_major_version >= 2.1:
        # apply mixed_precision for valid TF version
        from tensorflow.keras.mixed_precision import experimental as mixed_precision

        policy = mixed_precision.Policy('mixed_float16')
        mixed_precision.set_policy(policy)
    else:
        raise ValueError('Tensorflow {} does not support mixed precision'.format(tf.__version__))

# %%
# get train/val dataset
train_generator = hourglass_dataset(dataset_path, batch_size, class_names,
                                    input_shape=model_input_shape,
                                    num_hgstack=num_stacks,
                                    is_train=True,
                                    with_meta=False,
                                    matchpoints=matchpoints)

num_train = train_generator.get_dataset_size()
num_val = len(train_generator.get_val_annotations())

model_type = get_model_type(num_stacks, mobile, tiny, model_input_shape)

# %%
# callbacks for training process
tensorboard = TensorBoard(log_dir=log_dir, histogram_freq=0, write_graph=True, write_grads=False, write_images=False, update_freq='batch')
eval_callback = EvalCallBack(log_dir, dataset_path, class_names, model_input_shape, model_type)
checkpoint_clean = CheckpointCleanCallBack(log_dir, max_val_keep=5)
terminate_on_nan = TerminateOnNaN()

callbacks = [tensorboard, eval_callback, terminate_on_nan, checkpoint_clean]
# callbacks = [tensorboard, terminate_on_nan, checkpoint_clean]

# prepare optimizer
steps_per_epoch = max(1, num_train//batch_size)
decay_steps = steps_per_epoch * (total_epoch - init_epoch)
optimizer = get_optimizer(optimizer, learning_rate, decay_type=decay_type, decay_steps=decay_steps)
#optimizer = RMSprop(lr=5e-4)

# prepare loss function
loss_func = get_loss(loss_type)

# %%
# support multi-gpu training
if gpu_num >= 2:
    # devices_list=["/gpu:0", "/gpu:1"]
    devices_list=["/gpu:{}".format(n) for n in range(gpu_num)]
    strategy = tf.distribute.MirroredStrategy(devices=devices_list)
    print ('Number of devices: {}'.format(strategy.num_replicas_in_sync))
    with strategy.scope():
        # get multi-gpu train model. you can also use "model_input_shape=None" to create a dynamic input shape model,
        # but multiscale train/inference doesn't work for it
        model = get_hourglass_model(num_classes, num_stacks, num_channels, model_input_shape=model_input_shape, mobile=mobile)
        # compile model
        model.compile(optimizer=optimizer, loss=loss_func)
else:
    # get normal train model. you can also use "model_input_shape=None" to create a dynamic input shape model,
    # but multiscale train/inference doesn't work for it
    model = get_hourglass_model(num_classes, num_stacks, num_channels, model_input_shape=model_input_shape, mobile=mobile)
    # compile model
    model.compile(optimizer=optimizer, loss=loss_func)

print('Create {} Stacked Hourglass model with stack number {}, channel number {}. train input shape {}'.format('Mobile' if mobile else '', num_stacks, num_channels, model_input_shape))
model.summary()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# Number of devices: 2
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Create  Stacked Hourglass model with stack number 2, channel number 256. train input shape (256, 256)
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  image_input (InputLayer)       [(None, 256, 256, 3  0           []
#                                 )]
#
#  front_conv_1x1_1 (Conv2D)      (None, 128, 128, 64  9472        ['image_input[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 64  256        ['front_conv_1x1_1[0][0]']
#  alization)                     )
#
#  front_residual_1_conv_1x1_1 (C  (None, 128, 128, 64  4160       ['batch_normalization[0][0]']
#  onv2D)                         )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 64  256        ['front_residual_1_conv_1x1_1[0][
#  rmalization)                   )                                0]']
#
#  front_residual_1_conv_3x3_2 (C  (None, 128, 128, 64  36928      ['batch_normalization_1[0][0]']
#  onv2D)                         )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 64  256        ['front_residual_1_conv_3x3_2[0][
#  rmalization)                   )                                0]']
#
#  front_residual_1_conv_1x1_3 (C  (None, 128, 128, 12  8320       ['batch_normalization_2[0][0]']
#  onv2D)                         8)
#
#  front_residual_1_skip (Conv2D)  (None, 128, 128, 12  8320       ['batch_normalization[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 12  512        ['front_residual_1_conv_1x1_3[0][
#  rmalization)                   8)                               0]']
#
#  front_residual_1_add (Add)     (None, 128, 128, 12  0           ['front_residual_1_skip[0][0]',
#                                 8)                                'batch_normalization_3[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 128)  0           ['front_residual_1_add[0][0]']
#
#  front_residual_2_conv_1x1_1 (C  (None, 64, 64, 64)  8256        ['max_pooling2d[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 64)  256         ['front_residual_2_conv_1x1_1[0][
#  rmalization)                                                    0]']
#
#  front_residual_2_conv_3x3_2 (C  (None, 64, 64, 64)  36928       ['batch_normalization_4[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 64)  256         ['front_residual_2_conv_3x3_2[0][
#  rmalization)                                                    0]']
#
#  front_residual_2_conv_1x1_3 (C  (None, 64, 64, 128)  8320       ['batch_normalization_5[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 128)  512        ['front_residual_2_conv_1x1_3[0][
#  rmalization)                                                    0]']
#
#  front_residual_2_add (Add)     (None, 64, 64, 128)  0           ['max_pooling2d[0][0]',
#                                                                   'batch_normalization_6[0][0]']
#
#  front_residual_3_conv_1x1_1 (C  (None, 64, 64, 128)  16512      ['front_residual_2_add[0][0]']
#  onv2D)
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 128)  512        ['front_residual_3_conv_1x1_1[0][
#  rmalization)                                                    0]']
#
#  front_residual_3_conv_3x3_2 (C  (None, 64, 64, 128)  147584     ['batch_normalization_7[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 64, 64, 128)  512        ['front_residual_3_conv_3x3_2[0][
#  rmalization)                                                    0]']
#
#  front_residual_3_conv_1x1_3 (C  (None, 64, 64, 256)  33024      ['batch_normalization_8[0][0]']
#  onv2D)
#
#  front_residual_3_skip (Conv2D)  (None, 64, 64, 256)  33024      ['front_residual_2_add[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 64, 64, 256)  1024       ['front_residual_3_conv_1x1_3[0][
#  rmalization)                                                    0]']
#
#  front_residual_3_add (Add)     (None, 64, 64, 256)  0           ['front_residual_3_skip[0][0]',
#                                                                   'batch_normalization_9[0][0]']
#
#  hg0_downsample_1_conv_1x1_1 (C  (None, 64, 64, 128)  32896      ['front_residual_3_add[0][0]']
#  onv2D)
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 128)  512        ['hg0_downsample_1_conv_1x1_1[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_1_conv_3x3_2 (C  (None, 64, 64, 128)  147584     ['batch_normalization_10[0][0]']
#  onv2D)
#
#  batch_normalization_11 (BatchN  (None, 64, 64, 128)  512        ['hg0_downsample_1_conv_3x3_2[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_1_conv_1x1_3 (C  (None, 64, 64, 256)  33024      ['batch_normalization_11[0][0]']
#  onv2D)
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 256)  1024       ['hg0_downsample_1_conv_1x1_3[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_1_add (Add)     (None, 64, 64, 256)  0           ['front_residual_3_add[0][0]',
#                                                                   'batch_normalization_12[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 256)  0          ['hg0_downsample_1_add[0][0]']
#
#  hg0_downsample_2_conv_1x1_1 (C  (None, 32, 32, 128)  32896      ['max_pooling2d_1[0][0]']
#  onv2D)
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 128)  512        ['hg0_downsample_2_conv_1x1_1[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_2_conv_3x3_2 (C  (None, 32, 32, 128)  147584     ['batch_normalization_13[0][0]']
#  onv2D)
#
#  batch_normalization_14 (BatchN  (None, 32, 32, 128)  512        ['hg0_downsample_2_conv_3x3_2[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_2_conv_1x1_3 (C  (None, 32, 32, 256)  33024      ['batch_normalization_14[0][0]']
#  onv2D)
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 256)  1024       ['hg0_downsample_2_conv_1x1_3[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_2_add (Add)     (None, 32, 32, 256)  0           ['max_pooling2d_1[0][0]',
#                                                                   'batch_normalization_15[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0          ['hg0_downsample_2_add[0][0]']
#
#  hg0_downsample_4_conv_1x1_1 (C  (None, 16, 16, 128)  32896      ['max_pooling2d_2[0][0]']
#  onv2D)
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 128)  512        ['hg0_downsample_4_conv_1x1_1[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_4_conv_3x3_2 (C  (None, 16, 16, 128)  147584     ['batch_normalization_16[0][0]']
#  onv2D)
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 128)  512        ['hg0_downsample_4_conv_3x3_2[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_4_conv_1x1_3 (C  (None, 16, 16, 256)  33024      ['batch_normalization_17[0][0]']
#  onv2D)
#
#  batch_normalization_18 (BatchN  (None, 16, 16, 256)  1024       ['hg0_downsample_4_conv_1x1_3[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_4_add (Add)     (None, 16, 16, 256)  0           ['max_pooling2d_2[0][0]',
#                                                                   'batch_normalization_18[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['hg0_downsample_4_add[0][0]']
#
#  hg0_downsample_8_conv_1x1_1 (C  (None, 8, 8, 128)   32896       ['max_pooling2d_3[0][0]']
#  onv2D)
#
#  batch_normalization_19 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_8_conv_1x1_1[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_8_conv_3x3_2 (C  (None, 8, 8, 128)   147584      ['batch_normalization_19[0][0]']
#  onv2D)
#
#  batch_normalization_20 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_8_conv_3x3_2[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_8_conv_1x1_3 (C  (None, 8, 8, 256)   33024       ['batch_normalization_20[0][0]']
#  onv2D)
#
#  batch_normalization_21 (BatchN  (None, 8, 8, 256)   1024        ['hg0_downsample_8_conv_1x1_3[0][
#  ormalization)                                                   0]']
#
#  hg0_downsample_8_add (Add)     (None, 8, 8, 256)    0           ['max_pooling2d_3[0][0]',
#                                                                   'batch_normalization_21[0][0]']
#
#  hg0_downsample_f8_1_conv_1x1_1  (None, 8, 8, 128)   32896       ['hg0_downsample_8_add[0][0]']
#   (Conv2D)
#
#  batch_normalization_25 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_f8_1_conv_1x1_1[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_1_conv_3x3_2  (None, 8, 8, 128)   147584      ['batch_normalization_25[0][0]']
#   (Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_f8_1_conv_3x3_2[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_1_conv_1x1_3  (None, 8, 8, 256)   33024       ['batch_normalization_26[0][0]']
#   (Conv2D)
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 256)   1024        ['hg0_downsample_f8_1_conv_1x1_3[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_1_add (Add)  (None, 8, 8, 256)    0           ['hg0_downsample_8_add[0][0]',
#                                                                   'batch_normalization_27[0][0]']
#
#  hg0_downsample_f8_2_conv_1x1_1  (None, 8, 8, 128)   32896       ['hg0_downsample_f8_1_add[0][0]']
#   (Conv2D)
#
#  batch_normalization_28 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_f8_2_conv_1x1_1[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_2_conv_3x3_2  (None, 8, 8, 128)   147584      ['batch_normalization_28[0][0]']
#   (Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_f8_2_conv_3x3_2[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_2_conv_1x1_3  (None, 8, 8, 256)   33024       ['batch_normalization_29[0][0]']
#   (Conv2D)
#
#  batch_normalization_30 (BatchN  (None, 8, 8, 256)   1024        ['hg0_downsample_f8_2_conv_1x1_3[
#  ormalization)                                                   0][0]']
#
#  hg0_downsample_f8_2_add (Add)  (None, 8, 8, 256)    0           ['hg0_downsample_f8_1_add[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  hg0_downsample_f8_3_conv_1x1_1  (None, 8, 8, 128)   32896       ['hg0_downsample_f8_2_add[0][0]']
#   (Conv2D)
#
#  hg0_downsample_f8_short_conv_1  (None, 8, 8, 128)   32896       ['hg0_downsample_8_add[0][0]']
#  x1_1 (Conv2D)
#
#  batch_normalization_31 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_f8_3_conv_1x1_1[
#  ormalization)                                                   0][0]']
#
#  batch_normalization_22 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_f8_short_conv_1x
#  ormalization)                                                   1_1[0][0]']
#
#  hg0_upsample_f4_short_conv_1x1  (None, 16, 16, 128)  32896      ['hg0_downsample_4_add[0][0]']
#  _1 (Conv2D)
#
#  hg0_downsample_f8_3_conv_3x3_2  (None, 8, 8, 128)   147584      ['batch_normalization_31[0][0]']
#   (Conv2D)
#
#  hg0_downsample_f8_short_conv_3  (None, 8, 8, 128)   147584      ['batch_normalization_22[0][0]']
#  x3_2 (Conv2D)
#
#  batch_normalization_34 (BatchN  (None, 16, 16, 128)  512        ['hg0_upsample_f4_short_conv_1x1_
#  ormalization)                                                   1[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_f8_3_conv_3x3_2[
#  ormalization)                                                   0][0]']
#
#  batch_normalization_23 (BatchN  (None, 8, 8, 128)   512         ['hg0_downsample_f8_short_conv_3x
#  ormalization)                                                   3_2[0][0]']
#
#  hg0_upsample_f4_short_conv_3x3  (None, 16, 16, 128)  147584     ['batch_normalization_34[0][0]']
#  _2 (Conv2D)
#
#  hg0_downsample_f8_3_conv_1x1_3  (None, 8, 8, 256)   33024       ['batch_normalization_32[0][0]']
#   (Conv2D)
#
#  hg0_downsample_f8_short_conv_1  (None, 8, 8, 256)   33024       ['batch_normalization_23[0][0]']
#  x1_3 (Conv2D)
#
#  batch_normalization_35 (BatchN  (None, 16, 16, 128)  512        ['hg0_upsample_f4_short_conv_3x3_
#  ormalization)                                                   2[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 8, 8, 256)   1024        ['hg0_downsample_f8_3_conv_1x1_3[
#  ormalization)                                                   0][0]']
#
#  batch_normalization_24 (BatchN  (None, 8, 8, 256)   1024        ['hg0_downsample_f8_short_conv_1x
#  ormalization)                                                   1_3[0][0]']
#
#  hg0_upsample_f4_short_conv_1x1  (None, 16, 16, 256)  33024      ['batch_normalization_35[0][0]']
#  _3 (Conv2D)
#
#  hg0_downsample_f8_3_add (Add)  (None, 8, 8, 256)    0           ['hg0_downsample_f8_2_add[0][0]',
#                                                                   'batch_normalization_33[0][0]']
#
#  hg0_downsample_f8_short_add (A  (None, 8, 8, 256)   0           ['hg0_downsample_8_add[0][0]',
#  dd)                                                              'batch_normalization_24[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 16, 16, 256)  1024       ['hg0_upsample_f4_short_conv_1x1_
#  ormalization)                                                   3[0][0]']
#
#  add (Add)                      (None, 8, 8, 256)    0           ['hg0_downsample_f8_3_add[0][0]',
#                                                                   'hg0_downsample_f8_short_add[0][
#                                                                  0]']
#
#  hg0_upsample_f4_short_add (Add  (None, 16, 16, 256)  0          ['hg0_downsample_4_add[0][0]',
#  )                                                                'batch_normalization_36[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 256)  0           ['add[0][0]']
#
#  add_1 (Add)                    (None, 16, 16, 256)  0           ['hg0_upsample_f4_short_add[0][0]
#                                                                  ',
#                                                                   'up_sampling2d[0][0]']
#
#  hg0_upsample_f4_merged_conv_1x  (None, 16, 16, 128)  32896      ['add_1[0][0]']
#  1_1 (Conv2D)
#
#  hg0_upsample_f2_short_conv_1x1  (None, 32, 32, 128)  32896      ['hg0_downsample_2_add[0][0]']
#  _1 (Conv2D)
#
#  batch_normalization_37 (BatchN  (None, 16, 16, 128)  512        ['hg0_upsample_f4_merged_conv_1x1
#  ormalization)                                                   _1[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 32, 32, 128)  512        ['hg0_upsample_f2_short_conv_1x1_
#  ormalization)                                                   1[0][0]']
#
#  hg0_upsample_f4_merged_conv_3x  (None, 16, 16, 128)  147584     ['batch_normalization_37[0][0]']
#  3_2 (Conv2D)
#
#  hg0_upsample_f2_short_conv_3x3  (None, 32, 32, 128)  147584     ['batch_normalization_40[0][0]']
#  _2 (Conv2D)
#
#  batch_normalization_38 (BatchN  (None, 16, 16, 128)  512        ['hg0_upsample_f4_merged_conv_3x3
#  ormalization)                                                   _2[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 32, 32, 128)  512        ['hg0_upsample_f2_short_conv_3x3_
#  ormalization)                                                   2[0][0]']
#
#  hg0_upsample_f4_merged_conv_1x  (None, 16, 16, 256)  33024      ['batch_normalization_38[0][0]']
#  1_3 (Conv2D)
#
#  hg0_upsample_f2_short_conv_1x1  (None, 32, 32, 256)  33024      ['batch_normalization_41[0][0]']
#  _3 (Conv2D)
#
#  batch_normalization_39 (BatchN  (None, 16, 16, 256)  1024       ['hg0_upsample_f4_merged_conv_1x1
#  ormalization)                                                   _3[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 32, 32, 256)  1024       ['hg0_upsample_f2_short_conv_1x1_
#  ormalization)                                                   3[0][0]']
#
#  hg0_upsample_f4_merged_add (Ad  (None, 16, 16, 256)  0          ['add_1[0][0]',
#  d)                                                               'batch_normalization_39[0][0]']
#
#  hg0_upsample_f2_short_add (Add  (None, 32, 32, 256)  0          ['hg0_downsample_2_add[0][0]',
#  )                                                                'batch_normalization_42[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 256)  0          ['hg0_upsample_f4_merged_add[0][0
#                                                                  ]']
#
#  add_2 (Add)                    (None, 32, 32, 256)  0           ['hg0_upsample_f2_short_add[0][0]
#                                                                  ',
#                                                                   'up_sampling2d_1[0][0]']
#
#  hg0_upsample_f2_merged_conv_1x  (None, 32, 32, 128)  32896      ['add_2[0][0]']
#  1_1 (Conv2D)
#
#  hg0_upsample_f1_short_conv_1x1  (None, 64, 64, 128)  32896      ['hg0_downsample_1_add[0][0]']
#  _1 (Conv2D)
#
#  batch_normalization_43 (BatchN  (None, 32, 32, 128)  512        ['hg0_upsample_f2_merged_conv_1x1
#  ormalization)                                                   _1[0][0]']
#
#  batch_normalization_46 (BatchN  (None, 64, 64, 128)  512        ['hg0_upsample_f1_short_conv_1x1_
#  ormalization)                                                   1[0][0]']
#
#  hg0_upsample_f2_merged_conv_3x  (None, 32, 32, 128)  147584     ['batch_normalization_43[0][0]']
#  3_2 (Conv2D)
#
#  hg0_upsample_f1_short_conv_3x3  (None, 64, 64, 128)  147584     ['batch_normalization_46[0][0]']
#  _2 (Conv2D)
#
#  batch_normalization_44 (BatchN  (None, 32, 32, 128)  512        ['hg0_upsample_f2_merged_conv_3x3
#  ormalization)                                                   _2[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 64, 64, 128)  512        ['hg0_upsample_f1_short_conv_3x3_
#  ormalization)                                                   2[0][0]']
#
#  hg0_upsample_f2_merged_conv_1x  (None, 32, 32, 256)  33024      ['batch_normalization_44[0][0]']
#  1_3 (Conv2D)
#
#  hg0_upsample_f1_short_conv_1x1  (None, 64, 64, 256)  33024      ['batch_normalization_47[0][0]']
#  _3 (Conv2D)
#
#  batch_normalization_45 (BatchN  (None, 32, 32, 256)  1024       ['hg0_upsample_f2_merged_conv_1x1
#  ormalization)                                                   _3[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 64, 64, 256)  1024       ['hg0_upsample_f1_short_conv_1x1_
#  ormalization)                                                   3[0][0]']
#
#  hg0_upsample_f2_merged_add (Ad  (None, 32, 32, 256)  0          ['add_2[0][0]',
#  d)                                                               'batch_normalization_45[0][0]']
#
#  hg0_upsample_f1_short_add (Add  (None, 64, 64, 256)  0          ['hg0_downsample_1_add[0][0]',
#  )                                                                'batch_normalization_48[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 256)  0          ['hg0_upsample_f2_merged_add[0][0
#                                                                  ]']
#
#  add_3 (Add)                    (None, 64, 64, 256)  0           ['hg0_upsample_f1_short_add[0][0]
#                                                                  ',
#                                                                   'up_sampling2d_2[0][0]']
#
#  hg0_upsample_f1_merged_conv_1x  (None, 64, 64, 128)  32896      ['add_3[0][0]']
#  1_1 (Conv2D)
#
#  batch_normalization_49 (BatchN  (None, 64, 64, 128)  512        ['hg0_upsample_f1_merged_conv_1x1
#  ormalization)                                                   _1[0][0]']
#
#  hg0_upsample_f1_merged_conv_3x  (None, 64, 64, 128)  147584     ['batch_normalization_49[0][0]']
#  3_2 (Conv2D)
#
#  batch_normalization_50 (BatchN  (None, 64, 64, 128)  512        ['hg0_upsample_f1_merged_conv_3x3
#  ormalization)                                                   _2[0][0]']
#
#  hg0_upsample_f1_merged_conv_1x  (None, 64, 64, 256)  33024      ['batch_normalization_50[0][0]']
#  1_3 (Conv2D)
#
#  batch_normalization_51 (BatchN  (None, 64, 64, 256)  1024       ['hg0_upsample_f1_merged_conv_1x1
#  ormalization)                                                   _3[0][0]']
#
#  hg0_upsample_f1_merged_add (Ad  (None, 64, 64, 256)  0          ['add_3[0][0]',
#  d)                                                               'batch_normalization_51[0][0]']
#
#  hg0_conv_1x1_1 (Conv2D)        (None, 64, 64, 256)  65792       ['hg0_upsample_f1_merged_add[0][0
#                                                                  ]']
#
#  batch_normalization_52 (BatchN  (None, 64, 64, 256)  1024       ['hg0_conv_1x1_1[0][0]']
#  ormalization)
#
#  hg0_conv_1x1_predict (Conv2D)  (None, 64, 64, 16)   4112        ['batch_normalization_52[0][0]']
#
#  hg0_conv_1x1_2 (Conv2D)        (None, 64, 64, 256)  65792       ['batch_normalization_52[0][0]']
#
#  hg0_conv_1x1_3 (Conv2D)        (None, 64, 64, 256)  4352        ['hg0_conv_1x1_predict[0][0]']
#
#  add_4 (Add)                    (None, 64, 64, 256)  0           ['hg0_conv_1x1_2[0][0]',
#                                                                   'hg0_conv_1x1_3[0][0]',
#                                                                   'front_residual_3_add[0][0]']
#
#  hg1_downsample_1_conv_1x1_1 (C  (None, 64, 64, 128)  32896      ['add_4[0][0]']
#  onv2D)
#
#  batch_normalization_53 (BatchN  (None, 64, 64, 128)  512        ['hg1_downsample_1_conv_1x1_1[0][
#  ormalization)                                                   0]']
#
#  hg1_downsample_1_conv_3x3_2 (C  (None, 64, 64, 128)  147584     ['batch_normalization_53[0][0]']
#  onv2D)
#
#  batch_normalization_54 (BatchN  (None, 64, 64, 128)  512        ['hg1_downsample_1_conv_3x3_2[0][
#  ormalization)                                                   0]']
#
#  hg1_downsample_1_conv_1x1_3 (C  (None, 64, 64, 256)  33024      ['batch_normalization_54[0][0]']
#  onv2D)
#
#  batch_normalization_55 (BatchN  (None, 64, 64, 256)  1024       ['hg1_downsample_1_conv_1x1_3[0][
#  ormalization)                                                   0]']
#
#  hg1_downsample_1_add (Add)     (None, 64, 64, 256)  0           ['add_4[0][0]',
#                                                                   'batch_normalization_55[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 256)  0          ['hg1_downsample_1_add[0][0]']
#
#  hg1_downsample_2_conv_1x1_1 (C  (None, 32, 32, 128)  32896      ['max_pooling2d_4[0][0]']
#  onv2D)
#
#  batch_normalization_56 (BatchN  (None, 32, 32, 128)  512        ['hg1_downsample_2_conv_1x1_1[0][
#  ormalization)                                                   0]']
#
#  hg1_downsample_2_conv_3x3_2 (C  (None, 32, 32, 128)  147584     ['batch_normalization_56[0][0]']
#  onv2D)
#
#  batch_normalization_57 (BatchN  (None, 32, 32, 128)  512        ['hg1_downsample_2_conv_3x3_2[0][
#  ormalization)                                                   0]']
#
#  hg1_downsample_2_conv_1x1_3 (C  (None, 32, 32, 256)  33024      ['batch_normalization_57[0][0]']
#  onv2D)
#
#  batch_normalization_58 (BatchN  (None, 32, 32, 256)  1024       ['hg1_downsample_2_conv_1x1_3[0][
#  ormalization)                                                   0]']
#
#  hg1_downsample_2_add (Add)     (None, 32, 32, 256)  0           ['max_pooling2d_4[0][0]',
#                                                                   'batch_normalization_58[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 256)  0          ['hg1_downsample_2_add[0][0]']
# ...
#  batch_normalization_67 (BatchN  (None, 8, 8, 256)   1024        ['hg1_downsample_f8_short_conv_1x
#  ormalization)                                                   1_3[0][0]']
#
#  hg1_upsample_f4_short_conv_1x1  (None, 16, 16, 256)  33024      ['batch_normalization_78[0][0]']
#  _3 (Conv2D)
#
#  hg1_downsample_f8_3_add (Add)  (None, 8, 8, 256)    0           ['hg1_downsample_f8_2_add[0][0]',
#                                                                   'batch_normalization_76[0][0]']
#
#  hg1_downsample_f8_short_add (A  (None, 8, 8, 256)   0           ['hg1_downsample_8_add[0][0]',
#  dd)                                                              'batch_normalization_67[0][0]']
#
#  batch_normalization_79 (BatchN  (None, 16, 16, 256)  1024       ['hg1_upsample_f4_short_conv_1x1_
#  ormalization)                                                   3[0][0]']
#
#  add_5 (Add)                    (None, 8, 8, 256)    0           ['hg1_downsample_f8_3_add[0][0]',
#                                                                   'hg1_downsample_f8_short_add[0][
#                                                                  0]']
#
#  hg1_upsample_f4_short_add (Add  (None, 16, 16, 256)  0          ['hg1_downsample_4_add[0][0]',
#  )                                                                'batch_normalization_79[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 16, 16, 256)  0          ['add_5[0][0]']
#
#  add_6 (Add)                    (None, 16, 16, 256)  0           ['hg1_upsample_f4_short_add[0][0]
#                                                                  ',
#                                                                   'up_sampling2d_3[0][0]']
#
#  hg1_upsample_f4_merged_conv_1x  (None, 16, 16, 128)  32896      ['add_6[0][0]']
#  1_1 (Conv2D)
#
#  hg1_upsample_f2_short_conv_1x1  (None, 32, 32, 128)  32896      ['hg1_downsample_2_add[0][0]']
#  _1 (Conv2D)
#
#  batch_normalization_80 (BatchN  (None, 16, 16, 128)  512        ['hg1_upsample_f4_merged_conv_1x1
#  ormalization)                                                   _1[0][0]']
#
#  batch_normalization_83 (BatchN  (None, 32, 32, 128)  512        ['hg1_upsample_f2_short_conv_1x1_
#  ormalization)                                                   1[0][0]']
#
#  hg1_upsample_f4_merged_conv_3x  (None, 16, 16, 128)  147584     ['batch_normalization_80[0][0]']
#  3_2 (Conv2D)
#
#  hg1_upsample_f2_short_conv_3x3  (None, 32, 32, 128)  147584     ['batch_normalization_83[0][0]']
#  _2 (Conv2D)
#
#  batch_normalization_81 (BatchN  (None, 16, 16, 128)  512        ['hg1_upsample_f4_merged_conv_3x3
#  ormalization)                                                   _2[0][0]']
#
#  batch_normalization_84 (BatchN  (None, 32, 32, 128)  512        ['hg1_upsample_f2_short_conv_3x3_
#  ormalization)                                                   2[0][0]']
#
#  hg1_upsample_f4_merged_conv_1x  (None, 16, 16, 256)  33024      ['batch_normalization_81[0][0]']
#  1_3 (Conv2D)
#
#  hg1_upsample_f2_short_conv_1x1  (None, 32, 32, 256)  33024      ['batch_normalization_84[0][0]']
#  _3 (Conv2D)
#
#  batch_normalization_82 (BatchN  (None, 16, 16, 256)  1024       ['hg1_upsample_f4_merged_conv_1x1
#  ormalization)                                                   _3[0][0]']
#
#  batch_normalization_85 (BatchN  (None, 32, 32, 256)  1024       ['hg1_upsample_f2_short_conv_1x1_
#  ormalization)                                                   3[0][0]']
#
#  hg1_upsample_f4_merged_add (Ad  (None, 16, 16, 256)  0          ['add_6[0][0]',
#  d)                                                               'batch_normalization_82[0][0]']
#
#  hg1_upsample_f2_short_add (Add  (None, 32, 32, 256)  0          ['hg1_downsample_2_add[0][0]',
#  )                                                                'batch_normalization_85[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 32, 32, 256)  0          ['hg1_upsample_f4_merged_add[0][0
#                                                                  ]']
#
#  add_7 (Add)                    (None, 32, 32, 256)  0           ['hg1_upsample_f2_short_add[0][0]
#                                                                  ',
#                                                                   'up_sampling2d_4[0][0]']
#
#  hg1_upsample_f2_merged_conv_1x  (None, 32, 32, 128)  32896      ['add_7[0][0]']
#  1_1 (Conv2D)
#
#  hg1_upsample_f1_short_conv_1x1  (None, 64, 64, 128)  32896      ['hg1_downsample_1_add[0][0]']
#  _1 (Conv2D)
#
#  batch_normalization_86 (BatchN  (None, 32, 32, 128)  512        ['hg1_upsample_f2_merged_conv_1x1
#  ormalization)                                                   _1[0][0]']
#
#  batch_normalization_89 (BatchN  (None, 64, 64, 128)  512        ['hg1_upsample_f1_short_conv_1x1_
#  ormalization)                                                   1[0][0]']
#
#  hg1_upsample_f2_merged_conv_3x  (None, 32, 32, 128)  147584     ['batch_normalization_86[0][0]']
#  3_2 (Conv2D)
#
#  hg1_upsample_f1_short_conv_3x3  (None, 64, 64, 128)  147584     ['batch_normalization_89[0][0]']
#  _2 (Conv2D)
#
#  batch_normalization_87 (BatchN  (None, 32, 32, 128)  512        ['hg1_upsample_f2_merged_conv_3x3
#  ormalization)                                                   _2[0][0]']
#
#  batch_normalization_90 (BatchN  (None, 64, 64, 128)  512        ['hg1_upsample_f1_short_conv_3x3_
#  ormalization)                                                   2[0][0]']
#
#  hg1_upsample_f2_merged_conv_1x  (None, 32, 32, 256)  33024      ['batch_normalization_87[0][0]']
#  1_3 (Conv2D)
#
#  hg1_upsample_f1_short_conv_1x1  (None, 64, 64, 256)  33024      ['batch_normalization_90[0][0]']
#  _3 (Conv2D)
#
#  batch_normalization_88 (BatchN  (None, 32, 32, 256)  1024       ['hg1_upsample_f2_merged_conv_1x1
#  ormalization)                                                   _3[0][0]']
#
#  batch_normalization_91 (BatchN  (None, 64, 64, 256)  1024       ['hg1_upsample_f1_short_conv_1x1_
#  ormalization)                                                   3[0][0]']
#
#  hg1_upsample_f2_merged_add (Ad  (None, 32, 32, 256)  0          ['add_7[0][0]',
#  d)                                                               'batch_normalization_88[0][0]']
#
#  hg1_upsample_f1_short_add (Add  (None, 64, 64, 256)  0          ['hg1_downsample_1_add[0][0]',
#  )                                                                'batch_normalization_91[0][0]']
#
#  up_sampling2d_5 (UpSampling2D)  (None, 64, 64, 256)  0          ['hg1_upsample_f2_merged_add[0][0
#                                                                  ]']
#
#  add_8 (Add)                    (None, 64, 64, 256)  0           ['hg1_upsample_f1_short_add[0][0]
#                                                                  ',
#                                                                   'up_sampling2d_5[0][0]']
#
#  hg1_upsample_f1_merged_conv_1x  (None, 64, 64, 128)  32896      ['add_8[0][0]']
#  1_1 (Conv2D)
#
#  batch_normalization_92 (BatchN  (None, 64, 64, 128)  512        ['hg1_upsample_f1_merged_conv_1x1
#  ormalization)                                                   _1[0][0]']
#
#  hg1_upsample_f1_merged_conv_3x  (None, 64, 64, 128)  147584     ['batch_normalization_92[0][0]']
#  3_2 (Conv2D)
#
#  batch_normalization_93 (BatchN  (None, 64, 64, 128)  512        ['hg1_upsample_f1_merged_conv_3x3
#  ormalization)                                                   _2[0][0]']
#
#  hg1_upsample_f1_merged_conv_1x  (None, 64, 64, 256)  33024      ['batch_normalization_93[0][0]']
#  1_3 (Conv2D)
#
#  batch_normalization_94 (BatchN  (None, 64, 64, 256)  1024       ['hg1_upsample_f1_merged_conv_1x1
#  ormalization)                                                   _3[0][0]']
#
#  hg1_upsample_f1_merged_add (Ad  (None, 64, 64, 256)  0          ['add_8[0][0]',
#  d)                                                               'batch_normalization_94[0][0]']
#
#  hg1_conv_1x1_1 (Conv2D)        (None, 64, 64, 256)  65792       ['hg1_upsample_f1_merged_add[0][0
#                                                                  ]']
#
#  batch_normalization_95 (BatchN  (None, 64, 64, 256)  1024       ['hg1_conv_1x1_1[0][0]']
#  ormalization)
#
#  hg1_conv_1x1_predict (Conv2D)  (None, 64, 64, 16)   4112        ['batch_normalization_95[0][0]']
#
#  tf.stack (TFOpLambda)          (None, 64, 64, 16,   0           ['hg0_conv_1x1_predict[0][0]',
#                                 2)                                'hg1_conv_1x1_predict[0][0]']
#
# ==================================================================================================
# Total params: 6,602,656
# Trainable params: 6,570,784
# Non-trainable params: 31,872
# __________________________________________________________________________________________________

# %%
# if weights_path:
#     model.load_weights(weights_path, by_name=True)#, skip_mismatch=True)
#     print('Load weights {}.'.format(weights_path))

# # start training
# print('Train on {} samples, val on {} samples, with batch size {}, model input shape {}.'.format(num_train, num_val, batch_size, model_input_shape))
# model.fit_generator(generator=train_generator,
#                     steps_per_epoch=num_train // batch_size,
#                     epochs=total_epoch,
#                     initial_epoch=init_epoch,
#                     workers=1,
#                     use_multiprocessing=False,
#                     max_queue_size=10,
                    
#                     callbacks=callbacks)

# model.save(os.path.join(log_dir, 'trained_final.h5'))

# %%
output_shape = (int(model_input_shape[0]/4), int(model_input_shape[1]/4))
output_shape
# Out:
# (64, 64)

# %%
from common.data_utils import random_horizontal_flip, random_vertical_flip, random_brightness
from common.data_utils import random_grayscale, random_chroma, random_contrast, random_sharpness, random_blur, random_histeq, random_rotate_angle
from common.data_utils import crop_single_object, rotate_single_object, crop_image, normalize_image, transform_keypoints, generate_gt_heatmap
from PIL import Image


def map_dataset_to_image_heatmaps(imagefile, center, scale, keypoints):
            
    img = tf.io.read_file(imagefile)
    decoded_img = tf.io.decode_png(img, channels=3)
#     orig_img_shape = decoded_img.shape
    resized_img = tf.image.resize(decoded_img, model_input_shape)
    image = resized_img
    
#     image = tf.expand_dims(resized_img, axis=0)


#     img = tf.io.read_file(imagefile)
#     if img.mode != 'RGB':
#         img = img.convert('RGB')
#     image = np.array(img)
#     img.close()
    
#     image_shape = image.shape

    rotate_angle = 0
#     image = crop_image(image, center, scale, model_input_shape, rotate_angle)
    
    # transform keypoints to cropped image reference
#     transformed_keypoints = transform_keypoints(keypoints, center, scale, output_shape, rotate_angle)

        # in case we got an empty image, bypass the sample
#     if image is None:
#         return None, None, None
    
    # normalize image
#     image = normalize_image(image, self.get_color_mean())



    # Data Augmentation
#     image, keypoints = crop_single_object(image, keypoints, center, scale, model_input_shape)
    seed = tf.random.uniform(shape=[2], maxval=3, dtype=tf.int32)
    image = tf.image.stateless_random_brightness(image, max_delta=0.95, seed=seed)
    image = tf.image.stateless_random_contrast(image, lower=0.1, upper=0.9, seed=seed)
    image = tf.image.stateless_random_hue(image, 0.2, seed)
    image = tf.image.stateless_random_jpeg_quality(image, 75, 95, seed)
    image = tf.image.stateless_random_saturation(image, lower=0.5, upper=1.0, seed=seed)


    # Rescale keypoints from original_img_shape to output_shape
    resized_scale = tf.divide(orig_img_shape, model_input_shape)
    resized_scale = tf.concat([resized_scale, [1]], 0)  # adding third dimension for visibility dimension in the keypoints 
    keypoints = tf.multiply(keypoints, resized_scale)

    # generate ground truth keypoint heatmap
    gt_heatmap = generate_gt_heatmap(keypoints, output_shape)

    out_heatmaps = []
    for m in range(num_stacks):
        out_heatmaps.append(gt_heatmap)
        
    return (image, tf.stack(out_heatmaps, axis=-1))

# %%
import numpy as np
import json

def dataset_from_annotations(annotations, image_path, validation_set=False):

    image_filenames = []
    centers = []
    keypoints = []
    scales = []
    
    for annotation in annotations:
        image_filename = os.path.join(image_path, annotation['img_paths'])
        center = np.array(annotation['objpos'])
        keypoint = np.array(annotation['joint_self'])
        scale = annotation['scale_provided']
        
        # adjust center/scale slightly to avoid cropping limbs

        if center[0] != -1:
            center[1] = center[1] + 15 * scale
            scale = scale * 1.25
        
        if annotation['isValidation'] == validation_set:        
            image_filenames.append(image_filename)
            centers.append(center)
            keypoints.append(keypoint)
            scales.append(scale)
        else:
            pass
    img_filenames = tf.convert_to_tensor(image_filenames)
    img_centers = tf.convert_to_tensor(centers)
    img_scales = tf.convert_to_tensor(scales)
    img_keypoints = tf.convert_to_tensor(keypoints)
    return image_filenames, centers, scales, keypoints
  
                 
            
    
        
# dataset with tf.data.Dataset and training using model.fit()
json_file = "data/mpii/annotations.json"
image_path = "data/mpii/images/"
with open(json_file) as f:
    annotations = json.load(f)

# %%
img_filenames, img_centers, img_scales, img_keypoints = dataset_from_annotations(annotations, image_path,validation_set=False)   
tfdataset_train= tf.data.Dataset.from_tensor_slices((img_filenames, img_centers, img_scales, img_keypoints))

img_filenames, img_centers, img_scales, img_keypoints = dataset_from_annotations(annotations, image_path,validation_set=True)      
tfdataset_val= tf.data.Dataset.from_tensor_slices((img_filenames, img_centers, img_scales, img_keypoints))

# %%
from common.data_utils import generate_gt_heatmap, label_heatmap
import inspect

# converted_f = tf.autograph.to_graph(label_heatmap.python_function)
# print(inspect.getsource(converted_f))
# img_keypointsT[0].shape
# generate_gt_heatmap(img_keypoints[0], (64,64))

# %%
AUTOTUNE = tf.data.AUTOTUNE
tfdataset_mapped_train = tfdataset_train.map(map_dataset_to_image_heatmaps, num_parallel_calls=AUTOTUNE).batch(batch_size).prefetch(AUTOTUNE)
tfdataset_mapped_val = tfdataset_val.map(map_dataset_to_image_heatmaps, num_parallel_calls=AUTOTUNE).batch(batch_size).prefetch(AUTOTUNE)
# Out:
# [<tf.Tensor 'cond/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_1/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_1/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_1/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_1/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_2/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_2/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_2/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_2/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_3/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_3/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_3/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_3/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_4/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_4/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_4/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_4/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_5/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_5/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_5/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_5/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_6/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_6/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_6/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_6/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_7/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_7/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_7/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_7/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_8/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_8/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_8/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_9/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_9/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_9/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_9/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_10/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_10/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_10/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_10/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_11/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_11/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_11/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_11/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_12/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_12/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_12/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_12/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_13/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_13/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_13/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_13/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_14/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_14/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_14/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_14/Cast_3:0' shape=() dtype=int32>]
# [<tf.Tensor 'cond_15/Cast:0' shape=() dtype=int32>, <tf.Tensor 'cond_15/Cast_1:0' shape=() dtype=int32>] [<tf.Tensor 'cond_15/Cast_2:0' shape=() dtype=int32>, <tf.Tensor 'cond_15/Cast_3:0' shape=() dtype=int32>]

# %%
# changing GPU device configuration
# import tensorflow as tf
# physical_devices = tf.config.list_physical_devices('GPU')

# tf.config.set_logical_device_configuration(
#     physical_devices[0],
#     [tf.config.LogicalDeviceConfiguration(memory_limit=100),
#      tf.config.LogicalDeviceConfiguration(memory_limit=100)])
# logical_devices = tf.config.list_logical_devices('GPU')
# logical_devicesphysical_devices = tf.config.list_physical_devices('GPU')
# try:
#   tf.config.set_logical_device_configuration(
#     physical_devices[0],
#     [tf.config.LogicalDeviceConfiguration(memory_limit=100),
#      tf.config.LogicalDeviceConfiguration(memory_limit=100)])

#   logical_devices = tf.config.list_logical_devices('GPU')
#   assert len(logical_devices) == len(physical_devices) + 1

#   tf.config.set_logical_device_configuration(
#     physical_devices[0],
#     [tf.config.LogicalDeviceConfiguration(memory_limit=10),
#      tf.config.LogicalDeviceConfiguration(memory_limit=10)])
# except:
#   # Invalid device or cannot modify logical devices once initialized.
#   pass

# %%
# callbacks = [tensorboard, eval_callback, terminate_on_nan, checkpoint_clean]
callbacks = [tensorboard, terminate_on_nan, checkpoint_clean]

# %%
model.fit(tfdataset_mapped_train, 
          validation_data=tfdataset_mapped_val,
                    # steps_per_epoch=num_train // batch_size,
                    epochs=total_epoch,
                    initial_epoch=init_epoch,
                    workers=1,
                    use_multiprocessing=True,
                    max_queue_size=10,                    
                    callbacks=callbacks)
# Out:
# Epoch 1/100
# INFO:tensorflow:batch_all_reduce: 396 all-reduces with algorithm = nccl, num_packs = 1
# INFO:tensorflow:batch_all_reduce: 396 all-reduces with algorithm = nccl, num_packs = 1
#   6/348 [..............................] - ETA: 2:10 - loss: 1.1355WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.3757s vs `on_train_batch_end` time: 0.3989s). Check your callbacks.
# 348/348 [==============================] - 235s 452ms/step - loss: 0.0398 - val_loss: 0.0206
# Epoch 2/100
# 348/348 [==============================] - 149s 423ms/step - loss: 0.0022 - val_loss: 0.0086
# Epoch 3/100
# 348/348 [==============================] - 146s 416ms/step - loss: 0.0018 - val_loss: 0.0058
# Epoch 4/100
# 348/348 [==============================] - 146s 416ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 5/100
# 348/348 [==============================] - 147s 418ms/step - loss: 0.0017 - val_loss: 0.0035
# Epoch 6/100
# 348/348 [==============================] - 146s 416ms/step - loss: 0.0016 - val_loss: 0.0026
# Epoch 7/100
# 348/348 [==============================] - 147s 419ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 8/100
# 348/348 [==============================] - 145s 412ms/step - loss: 0.0015 - val_loss: 0.0043
# Epoch 9/100
# 348/348 [==============================] - 147s 418ms/step - loss: 0.0015 - val_loss: 0.0024
# Epoch 10/100
# 348/348 [==============================] - 147s 417ms/step - loss: 0.0015 - val_loss: 0.0034
# Epoch 11/100
# 348/348 [==============================] - 145s 415ms/step - loss: 0.0015 - val_loss: 0.0045
# Epoch 12/100
# 348/348 [==============================] - 146s 415ms/step - loss: 0.0015 - val_loss: 0.0036
# Epoch 13/100
# 348/348 [==============================] - 147s 419ms/step - loss: 0.0014 - val_loss: 0.0020
# Epoch 14/100
# 348/348 [==============================] - 146s 415ms/step - loss: 0.0014 - val_loss: 0.0029
# Epoch 15/100
# 348/348 [==============================] - 145s 413ms/step - loss: 0.0014 - val_loss: 0.0033
# Epoch 16/100
# 348/348 [==============================] - 145s 414ms/step - loss: 0.0014 - val_loss: 0.0018
# Epoch 17/100
# 348/348 [==============================] - 145s 413ms/step - loss: 0.0014 - val_loss: 0.0022
# Epoch 18/100
# 348/348 [==============================] - 144s 412ms/step - loss: 0.0014 - val_loss: 0.0023
# Epoch 19/100
# 348/348 [==============================] - 147s 420ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 20/100
# 348/348 [==============================] - 147s 417ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 21/100
# 348/348 [==============================] - 145s 413ms/step - loss: 0.0013 - val_loss: 0.0016
# Epoch 22/100
# 348/348 [==============================] - 148s 421ms/step - loss: 0.0013 - val_loss: 0.0022
# Epoch 23/100
# 348/348 [==============================] - 148s 421ms/step - loss: 0.0013 - val_loss: 0.0017
# Epoch 24/100
# 348/348 [==============================] - 147s 419ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 25/100
# 348/348 [==============================] - 144s 412ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 26/100
# 348/348 [==============================] - 147s 420ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 27/100
# 348/348 [==============================] - 145s 414ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 28/100
# 348/348 [==============================] - 145s 413ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 29/100
# 348/348 [==============================] - 145s 413ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 30/100
# 348/348 [==============================] - 147s 419ms/step - loss: 0.0012 - val_loss: 0.0014
# Epoch 31/100
# 348/348 [==============================] - 147s 419ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 32/100
# 348/348 [==============================] - 145s 413ms/step - loss: 0.0012 - val_loss: 0.0016
# Epoch 33/100
# 348/348 [==============================] - 147s 419ms/step - loss: 0.0012 - val_loss: 0.0012
# Epoch 34/100
# 348/348 [==============================] - 146s 416ms/step - loss: 0.0011 - val_loss: 9.9360e-04
# Epoch 35/100
# 348/348 [==============================] - 144s 411ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 36/100
# 348/348 [==============================] - 146s 416ms/step - loss: 0.0011 - val_loss: 0.0017
# Epoch 37/100
# 348/348 [==============================] - 146s 416ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 38/100
# 348/348 [==============================] - 144s 411ms/step - loss: 0.0011 - val_loss: 9.3888e-04
# Epoch 39/100
# 348/348 [==============================] - 146s 417ms/step - loss: 0.0011 - val_loss: 0.0055
# Epoch 40/100
# 348/348 [==============================] - 146s 415ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 41/100
# 348/348 [==============================] - 146s 417ms/step - loss: 0.0011 - val_loss: 0.0020
# Epoch 42/100
# 348/348 [==============================] - 146s 415ms/step - loss: 0.0011 - val_loss: 0.0019
# Epoch 43/100
# 348/348 [==============================] - 145s 412ms/step - loss: 0.0011 - val_loss: 0.0057
# Epoch 44/100
# 348/348 [==============================] - 145s 413ms/step - loss: 0.0011 - val_loss: 0.0059
# Epoch 45/100
# 348/348 [==============================] - 146s 416ms/step - loss: 0.0011 - val_loss: 0.0690
# Epoch 46/100
# 348/348 [==============================] - 145s 413ms/step - loss: 0.0011 - val_loss: 0.0032
# Epoch 47/100
# 348/348 [==============================] - 147s 419ms/step - loss: 0.0010 - val_loss: 0.0016
# Epoch 48/100
# 348/348 [==============================] - 146s 417ms/step - loss: 0.0010 - val_loss: 0.0018
# Epoch 49/100
# 348/348 [==============================] - 145s 413ms/step - loss: 0.0010 - val_loss: 0.0022
# Epoch 50/100
# 348/348 [==============================] - 145s 413ms/step - loss: 0.0010 - val_loss: 0.0023
# Epoch 51/100
# 348/348 [==============================] - 148s 422ms/step - loss: 0.0010 - val_loss: 0.0074
# Epoch 52/100
# 348/348 [==============================] - 145s 413ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 53/100
# 348/348 [==============================] - 144s 410ms/step - loss: 0.0010 - val_loss: 9.4300e-04
# Epoch 54/100
# 348/348 [==============================] - 145s 411ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 55/100
# 348/348 [==============================] - 145s 412ms/step - loss: 0.0010 - val_loss: 0.0282
# Epoch 56/100
# 348/348 [==============================] - 145s 414ms/step - loss: 0.0010 - val_loss: 8.7453e-04
# Epoch 57/100
# 348/348 [==============================] - 144s 411ms/step - loss: 9.9789e-04 - val_loss: 8.9330e-04
# Epoch 58/100
# 348/348 [==============================] - 146s 415ms/step - loss: 9.8809e-04 - val_loss: 0.2000
# Epoch 59/100
# 348/348 [==============================] - 145s 415ms/step - loss: 9.8139e-04 - val_loss: 0.0010
# Epoch 60/100
# 348/348 [==============================] - 146s 416ms/step - loss: 9.6928e-04 - val_loss: 0.0021
# Epoch 61/100
# 348/348 [==============================] - 145s 414ms/step - loss: 9.5931e-04 - val_loss: 0.0012
# Epoch 62/100
# 348/348 [==============================] - 145s 414ms/step - loss: 9.5004e-04 - val_loss: 0.0022
# Epoch 63/100
# 348/348 [==============================] - 147s 418ms/step - loss: 9.4031e-04 - val_loss: 0.0250
# Epoch 64/100
# 348/348 [==============================] - 144s 411ms/step - loss: 9.3135e-04 - val_loss: 0.0023
# Epoch 65/100
# 348/348 [==============================] - 146s 416ms/step - loss: 9.2218e-04 - val_loss: 0.0767
# Epoch 66/100
# 348/348 [==============================] - 145s 414ms/step - loss: 9.1434e-04 - val_loss: 0.0196
# Epoch 67/100
# 348/348 [==============================] - 145s 414ms/step - loss: 9.0830e-04 - val_loss: 0.1366
# Epoch 68/100
# 348/348 [==============================] - 146s 416ms/step - loss: 8.9958e-04 - val_loss: 8.3084e-04
# Epoch 69/100
# 348/348 [==============================] - 145s 415ms/step - loss: 8.9100e-04 - val_loss: 0.0016
# Epoch 70/100
# 348/348 [==============================] - 145s 413ms/step - loss: 8.8202e-04 - val_loss: 7.9874e-04
# Epoch 71/100
# 348/348 [==============================] - 146s 415ms/step - loss: 8.7371e-04 - val_loss: 0.0016
# Epoch 72/100
# 348/348 [==============================] - 145s 414ms/step - loss: 8.6501e-04 - val_loss: 0.0018
# Epoch 73/100
# 348/348 [==============================] - 145s 413ms/step - loss: 8.5674e-04 - val_loss: 0.0066
# Epoch 74/100
# 348/348 [==============================] - 146s 416ms/step - loss: 8.4949e-04 - val_loss: 9.9060e-04
# Epoch 75/100
# 348/348 [==============================] - 147s 418ms/step - loss: 8.4095e-04 - val_loss: 0.0187
# Epoch 76/100
# 348/348 [==============================] - 146s 416ms/step - loss: 8.3573e-04 - val_loss: 0.0021
# Epoch 77/100
# 348/348 [==============================] - 146s 415ms/step - loss: 8.2858e-04 - val_loss: 0.0029
# Epoch 78/100
# 348/348 [==============================] - 146s 417ms/step - loss: 8.1996e-04 - val_loss: 0.0678
# Epoch 79/100
# 348/348 [==============================] - 145s 414ms/step - loss: 8.4101e-04 - val_loss: 5.3709e-04
# Epoch 80/100
# 348/348 [==============================] - 146s 415ms/step - loss: 8.0774e-04 - val_loss: 0.0047
# Epoch 81/100
# 348/348 [==============================] - 145s 413ms/step - loss: 7.9746e-04 - val_loss: 0.0032
# Epoch 82/100
# 348/348 [==============================] - 147s 418ms/step - loss: 7.8768e-04 - val_loss: 0.0011
# Epoch 83/100
# 348/348 [==============================] - 145s 416ms/step - loss: 7.7956e-04 - val_loss: 0.0024
# Epoch 84/100
# 348/348 [==============================] - 142s 404ms/step - loss: 7.7270e-04 - val_loss: 0.0098
# Epoch 85/100
# 348/348 [==============================] - 145s 412ms/step - loss: 7.6526e-04 - val_loss: 0.0088
# Epoch 86/100
# 348/348 [==============================] - 146s 415ms/step - loss: 7.5423e-04 - val_loss: 0.0274
# Epoch 87/100
# 348/348 [==============================] - 145s 413ms/step - loss: 7.4472e-04 - val_loss: 0.0224
# Epoch 88/100
# 348/348 [==============================] - 145s 414ms/step - loss: 7.3417e-04 - val_loss: 0.0060
# Epoch 89/100
# 348/348 [==============================] - 146s 415ms/step - loss: 7.2578e-04 - val_loss: 0.0080
# Epoch 90/100
# 348/348 [==============================] - 144s 410ms/step - loss: 7.1943e-04 - val_loss: 0.0026
# Epoch 91/100
# 348/348 [==============================] - 149s 425ms/step - loss: 7.1319e-04 - val_loss: 6.1666e-04
# Epoch 92/100
# 348/348 [==============================] - 146s 415ms/step - loss: 7.0379e-04 - val_loss: 0.0025
# Epoch 93/100
# 348/348 [==============================] - 145s 414ms/step - loss: 6.9427e-04 - val_loss: 0.0012
# Epoch 94/100
# 348/348 [==============================] - 148s 422ms/step - loss: 6.8469e-04 - val_loss: 0.0044
# Epoch 95/100
# 348/348 [==============================] - 148s 421ms/step - loss: 6.7637e-04 - val_loss: 0.0513
# Epoch 96/100
# 348/348 [==============================] - 147s 419ms/step - loss: 6.7208e-04 - val_loss: 9.7319e-04
# Epoch 97/100
#  20/348 [>.............................] - ETA: 2:00 - loss: 6.6634e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 model.fit(tfdataset_mapped_train,
#       2           validation_data=tfdataset_mapped_val,
#       3                     # steps_per_epoch=num_train // batch_size,
#       4                     epochs=total_epoch,
#       5                     initial_epoch=init_epoch,
#       6                     workers=1,
#       7                     use_multiprocessing=True,
#       8                     max_queue_size=10,
#       9                     callbacks=callbacks)
#
# File /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py:64, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      62 filtered_tb = None
#      63 try:
# ---> 64   return fn(*args, **kwargs)
#      65 except Exception as e:  # pylint: disable=broad-except
#      66   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/keras/engine/training.py:1409, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1402 with tf.profiler.experimental.Trace(
#    1403     'train',
#    1404     epoch_num=epoch,
#    1405     step_num=step,
#    1406     batch_size=batch_size,
#    1407     _r=1):
#    1408   callbacks.on_train_batch_begin(step)
# -> 1409   tmp_logs = self.train_function(iterator)
#    1410   if data_handler.should_sync:
#    1411     context.async_wait()
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py:2453, in Function.__call__(self, *args, **kwargs)
#    2450 with self._lock:
#    2451   (graph_function,
#    2452    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2453 return graph_function._call_flat(
#    2454     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py:1860, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1856 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1857 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1858     and executing_eagerly):
#    1859   # No tape is watching; skip to running the function.
# -> 1860   return self._build_call_outputs(self._inference_function.call(
#    1861       ctx, args, cancellation_manager=cancellation_manager))
#    1862 forward_backward = self._select_forward_and_backward_functions(
#    1863     args,
#    1864     possible_gradient_type,
#    1865     executing_eagerly)
#    1866 forward_function, args_with_tangents = forward_backward.forward()
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/function.py:497, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     495 with _InterpolateFunctionError(self):
#     496   if cancellation_manager is None:
# --> 497     outputs = execute.execute(
#     498         str(self.signature.name),
#     499         num_outputs=self._num_outputs,
#     500         inputs=args,
#     501         attrs=attrs,
#     502         ctx=ctx)
#     503   else:
#     504     outputs = execute.execute_with_cancellation(
#     505         str(self.signature.name),
#     506         num_outputs=self._num_outputs,
#    (...)
#     509         ctx=ctx,
#     510         cancellation_manager=cancellation_manager)
#
# File /usr/local/lib/python3.8/dist-packages/tensorflow/python/eager/execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
# checkpoint_dir = os.path.join(log_dir, 'ep{epoch:03d}-loss{loss:.3f}-val_acc{val_acc:.3f}.h5'.format(epoch=(epoch+1), loss=logs.get('loss'), val_acc=val_acc))
epoch = 97
checkpoint_dir = os.path.join(log_dir, 'ep{epoch:03d}-loss{loss:.3f}.h5'.format(epoch=(epoch+1), loss=9.7319e-04))
model.save(checkpoint_dir)

# %%
eval_callback.model = model
eval_callback.on_epoch_end(0)

# %%
from eval import hourglass_predict_keras, post_process_heatmap_simple
heatmap = hourglass_predict_keras(model, data_item[0])

# %%
heatmap.shape[0:2]

# %%
post_process_heatmap_simple(heatmap, 0.01)

# %%
_map = heatmap[:, :,:, 0]
np.where(_map == _map.max())

# %%
num_train
